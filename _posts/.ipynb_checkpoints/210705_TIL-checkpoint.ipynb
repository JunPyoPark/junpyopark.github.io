# %% [markdown]
# # 210705 Today I Learned

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#시계열-Auto-Encoder-개선" data-toc-modified-id="시계열-Auto-Encoder-개선-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>시계열 Auto Encoder 개선</a></span><ul class="toc-item"><li><span><a href="#Reconstruct-Whole-Period-(Unroll-the-signal)" data-toc-modified-id="Reconstruct-Whole-Period-(Unroll-the-signal)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Reconstruct Whole Period (Unroll the signal)</a></span></li></ul></li><li><span><a href="#저널클럽-준비" data-toc-modified-id="저널클럽-준비-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>저널클럽 준비</a></span><ul class="toc-item"><li><span><a href="#가속화-모멘텀-코드-추가-작업-(논문에-있는-Figure-2-그리는-코드)" data-toc-modified-id="가속화-모멘텀-코드-추가-작업-(논문에-있는-Figure-2-그리는-코드)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>가속화 모멘텀 코드 추가 작업 (논문에 있는 Figure 2 그리는 코드)</a></span><ul class="toc-item"><li><span><a href="#Q-portfolio-Example" data-toc-modified-id="Q-portfolio-Example-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Q portfolio Example</a></span></li></ul></li></ul></li><li><span><a href="#Reading" data-toc-modified-id="Reading-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Reading</a></span><ul class="toc-item"><li><span><a href="#Article" data-toc-modified-id="Article-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Article</a></span></li><li><span><a href="#Paper" data-toc-modified-id="Paper-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Paper</a></span><ul class="toc-item"><li><span><a href="#Deep-Set:-Set으로-정의된-ML-task에-있어서-permutation-invariant-를-정의하고-이를-위한-objective-function의-특성-등을-정리-(아직-다-못-읽음)" data-toc-modified-id="Deep-Set:-Set으로-정의된-ML-task에-있어서-permutation-invariant-를-정의하고-이를-위한-objective-function의-특성-등을-정리-(아직-다-못-읽음)-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span><a href="https://arxiv.org/pdf/1703.06114.pdf" target="_blank">Deep Set</a>: Set으로 정의된 ML task에 있어서 permutation invariant 를 정의하고 이를 위한 objective function의 특성 등을 정리 (아직 다 못 읽음)</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## 시계열 Auto Encoder 개선

# %% [markdown]
# ### Reconstruct Whole Period (Unroll the signal)
# * Whole Period Reconstruction 모듈 제작 완료
# * Reference: [Time Series Anomaly Detection in the era of deep learning](https://medium.com/mit-data-to-ai-lab/time-series-anomaly-detection-in-the-era-of-deep-learning-f0237902224a)

# %% [markdown]
# ![](https://miro.medium.com/max/945/1*qnWtFo2TfXED5XdjGUAPYQ.png)

# %% [markdown]
# * Variance가 작아지는 문제 해결 해야 함

# %% [markdown]
# ## 저널클럽 준비
# ### 가속화 모멘텀 코드 추가 작업 (논문에 있는 Figure 2 그리는 코드)

# %%
q.plot(figsize=(10,5));

# %% [markdown]
# #### Q portfolio Example

# %%
Q = lag_port.Q

# %%
Q[1].tail()
# Out:
# 강원랜드      0.131846
# 스카이라이프    0.133877
# 한국가스공사    0.138937
# 부국철강      0.141686
# 한국내화      0.143035
# dtype: float64

# %%
Q[2].tail()
# Out:
# 진양화학     0.372881
# 쌍용C&E    0.374663
# 영풍       0.375984
# 유수홀딩스    0.376860
# 태경산업     0.379939
# dtype: float64

# %%
Q[3].tail()
# Out:
# KR모터스    0.591837
# 현대차증권    0.593220
# 원림       0.594735
# 모토닉      0.595052
# SK증권     0.595238
# dtype: float64

# %%
Q[4].tail()
# Out:
# 한세실업       1.011364
# 케이씨씨글라스    1.012442
# 에넥스        1.012712
# 팬오션        1.014577
# LS네트웍스     1.034301
# dtype: float64

# %%
Q[5].tail()
# Out:
# 서연       4.518248
# 포스코강판    4.555556
# 이스타코     5.184012
# 덕성       6.185629
# HMM      9.597652
# dtype: float64

# %% [markdown]
# ## Reading

# %% [markdown]
# ### Article
# <strong>[Lessons from the pandemic’s superstar data scientist, Youyang Gu](https://www.technologyreview.com/2021/04/27/1023657/lessons-from-the-pandemics-superstar-data-scientist-youyang-gu/)</strong>

# %% [markdown]
# <ul>
# <li>Lesson #1: Focus on fundamentals (심플한 모델, 데이터가 realistic 문제에 더 working 할 수 있다)
# <li>Lesson #2: Minimize assumptions (선입견을 제거하고 데이터를 봐라)
# <li>Lesson #3: Test the hypothesis (가설수립과 테스트는 unit action이다)
# <li>Lesson #4: Learn from mistakes (예측실패에 대해 분석 후 보완해라)
# <li>Lesson #5: Engage critics (비판적 사고와 토론으로 confirmation bias을 제거해라)
# <li>Lesson #6: Exercise healthy skepticism (건전한 회의주의 사고를 가져라)

# %% [markdown]
# ### Paper
#
# #### [Deep Set](https://arxiv.org/pdf/1703.06114.pdf): Set으로 정의된 ML task에 있어서 permutation invariant 를 정의하고 이를 위한 objective function의 특성 등을 정리 (아직 다 못 읽음)
